# %% [markdown]
# # Labo 8 : modèles de langage / Cloze Test
# Par Johanna Melly et Yohann Meyer

# %% [markdown]
# ## Objectif et plan

# %% [markdown]
# L'objectif de ce labo est d'entraîner des modèles de langues (EN : language models) sous NLTK en utilisant le package nltk.lm. Les modèles seront entraînés sur des romans de Balzac en français
# (fournis par le projet Gutenberg), et leurs performances seront mesurées par leur perplexité sur de nouveaux textes. Les modèles serviront également à deviner des mots cachés dans un texte, et ici leurs performances seront comparées à celles des humains sur cette même tâche.

# %% [markdown]
# ## Importation

# %%
import antigravity

# %% [markdown]
# ## Obtenir les données

# %% [markdown]
# Télécharger les dix romans de la Comédie humaine de Balzac en français, enlever les notices en anglais au début et à la fin, puis les assembler en un corpus.
# **NOTE : nous remercions le groupe de Vincent Guidoux et Nathan Gonzalez qui nous ont gentiment partagé leur fichier la_comedie_humaine.txt alors que le site de Gutenberg était down, afin que nous puissions tout de même réaliser le laboratoire**

# %%
from urllib import request

baseUrl = "http://www.gutenberg.org/files/"
comedieHumaine = ["43851/43851-0.txt", "45060/45060-0.txt", "48082/48082-0.txt", "49482/49482-0.txt", "51381/51381-0.txt", "52831/52831-0.txt", "54723/54723-0.txt", "55860/55860-0.txt", "58244/58244-0.txt"]
corpus = ''

for volume in comedieHumaine:
    response = request.urlopen(baseUrl+volume)
    raw = response.read().decode('utf-8')
    start = raw.find('Au lecteur')
    end = raw.rfind('End of')
    corpus+=raw[start:end]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-788f1d3d54b5> in <module>
#       6
#       7 for volume in comedieHumaine:
# ----> 8     response = request.urlopen(baseUrl+volume)
#       9     raw = response.read().decode('utf-8')
#      10     start = raw.find('Au lecteur')
#
# /usr/lib/python3.5/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# /usr/lib/python3.5/urllib/request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
#     468         # post-process response
#
# /usr/lib/python3.5/urllib/request.py in _open(self, req, data)
#     482         protocol = req.type
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#     486             return result
#
# /usr/lib/python3.5/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# /usr/lib/python3.5/urllib/request.py in http_open(self, req)
#    1280
#    1281     def http_open(self, req):
# -> 1282         return self.do_open(http.client.HTTPConnection, req)
#    1283
#    1284     http_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python3.5/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1255             except OSError as err: # timeout error
#    1256                 raise URLError(err)
# -> 1257             r = h.getresponse()
#    1258         except:
#    1259             h.close()
#
# /usr/lib/python3.5/http/client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# /usr/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/lib/python3.5/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/lib/python3.5/socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# Sauvegarder le texte résultant : quelle taille fait-il en Ko ou Mo?

# %%
import os, codecs
corpus = open('data/la_comedie_humaine.txt', 'r', encoding='utf-8').read()
print("Taille du fichier: " + str(os.path.getsize('data/la_comedie_humaine.txt')/1000000) + ' MB')
# Out:
# Taille du fichier: 12.552112 MB

# %% [markdown]
# Segmenter et tokenizer chacun des deux corpus (train/test) en une liste de listes de mots, y compris les ponctuations (une liste = une phrase).

# %%
import nltk
sents = nltk.sent_tokenize(corpus, language='french')
wordSents = [nltk.word_tokenize(s, language='french') for s in sents]
sents
# Out:
# ['\n\n\n\n\n\n\n\n\n\n  au lecteur\n\n  cette version numérisée reproduit, dans son intégralité,\n  la version originale.',
#  "la ponctuation n'a pas été modifiée hormis quelques corrections\n  mineures.",
#  "l'orthographe a été conservée.",
#  'seuls quelques mots ont été modifiés.',
#  'la liste des modifications se trouve à la fin du texte.',
#  'oeuvres complètes\n  de\n  h. de balzac\n\n\n  la comédie humaine\n\n  premier volume\n\n\n  première partie\n  études de moeurs\n\n\n  premier livre\n\n\n  paris.--imprimerie de e. martinet, rue mignon, 2\n\n  [illustration: balzac]\n\n\n\n\n  scènes\n  de\n  la vie privée\n\n  tome 1\n\n\n  la maison du chat-qui-pelote--le bal de sceaux\n  la bourse--la vendetta--madame firmiani\n  une double famille--la paix du ménage--la fausse maitresse\n  étude de femme--albert savarus\n\n\n  paris\n\n  veuve andre houssiaux, éditeur\n\n  hébert et cie, successeurs\n  7, rue perronet, 7\n\n  1874\n\n\n\n\nhonoré de balzac\n\n\nbalzac naquit à tours le 16 mai 1799, le jour de la fête de saint\nhonoré, dont on lui donna le nom, qui parut bien sonnant et de bon\naugure.',
#  "le petit honoré ne fut pas un enfant prodige; il n'annonça pas\nprématurément qu'il ferait la _comédie humaine_.",
#  "c'était un garçon\nfrais, vermeil, bien portant, joueur, aux yeux brillants et doux, mais\nque rien ne distinguait des autres, du moins à des regards peu\nattentifs.",
#  "a sept ans, au sortir d'un externat de tours, on le mit au\ncollége de vendôme, tenu par des oratoriens, où il passa pour un élève\ntrès-médiocre.",
#  'la première partie de _louis lambert_ contient sur ce temps de la vie de\nbalzac de curieux renseignements.',
#  "dédoublant sa personnalité, il s'y\npeint comme un ancien condisciple de louis lambert, tantôt en parlant en\nson nom, et tantôt prêtant ses propres sentiments à ce personnage\nimaginaire, mais pourtant très-réel, puisqu'il est une sorte d'objectif\nde l'âme même de l'écrivain.",
#  'balzac souffrit prodigieusement dans ce collége de vendôme, où sa nature\nrêveuse était meurtrie à chaque instant par une règle inflexible.',
#  "il\nnégligeait de faire ses devoirs; mais, favorisé par la complicité tacite\nd'un répétiteur de mathématiques, en même temps bibliothécaire et occupé\nde quelque ouvrage transcendental, il ne prenait pas sa leçon et\nemportait les livres qu'il voulait.",
#  'tout son temps se passait à lire en\ncachette.',
#  "aussi fut-il bientôt l'élève le plus puni de sa classe.",
#  "les\npensums, les retenues absorbèrent bientôt le temps des récréations; à\ncertaines natures d'écoliers, les châtiments inspirent une sorte de\nrébellion stoïque, et ils opposent aux professeurs exaspérés la même\nimpassibilité dédaigneuse que les guerriers sauvages captifs aux ennemis\nqui les torturent.",
#  "ni le cachot, ni la privation d'aliments, ni la\nférule ne parviennent à leur arracher la moindre plainte; ce sont alors,\nentre le maître et l'élève, des luttes horribles, inconnues des parents,\noù la constance des martyrs et l'habileté des bourreaux se trouvent\négalées.",
#  'quelques professeurs nerveux ne peuvent supporter le regard de\nhaine, de mépris et de menace par lequel un bambin de huit ou dix ans\nles brave.',
#  'le résultat de ces travaux cachés, de ces méditations qui prenaient le\ntemps des études, fut ce fameux _traité de la volonté_, dont il est\nparlé plusieurs fois dans la _comédie humaine_.',
#  "balzac regretta toujours\nla perte de cette première oeuvre, qu'il esquisse sommairement dans\n_louis lambert_, il dut être moins sensible à la perte de son poëme\népique sur les incas, inspiration malencontreuse qui lui valut, tout le\ntemps qu'il resta au collége, le sobriquet dérisoire de poëte.",
#  "balzac,\nil faut l'avouer, n'eut jamais le don de poésie, de versification, du\nmoins; sa pensée si complexe resta toujours rebelle au rhythme.",
#  'a propos de vers, consignons ici un petit renseignement qui pourra\namuser les curieux littéraires.',
#  'les quelques sonnets que lucien de\nrubempré fait voir comme échantillon de son volume de vers au libraire\ndauriat ne sont pas de balzac, qui ne faisait pas de vers, et demandait\nà ses amis ceux dont il avait besoin.',
#  'le sonnet de la _marguerite_ est\nde mme de girardin; le sonnet sur le _camellia_, de lassailly; celui\nsur la _tulipe_, de votre serviteur.',
#  "_modeste mignon_ renferme aussi une pièce de vers, mais nous en ignorons\nl'auteur.",
#  "pas plus dans la famille qu'au collége l'intelligence de balzac ne fut\ndevinée ou comprise.",
#  "même, s'il lui échappait quelque chose d'ingénieux,\nsa mère, femme supérieure cependant, lui disait: «sans doute, honoré, tu\nne comprends pas ce que tu dis là!» et balzac de rire, sans s'expliquer\ndavantage, de ce bon rire qu'il avait.",
#  'la famille de balzac étant revenue à paris, il fut mis en pension.',
#  'là,\ncomme au collége de vendôme, son génie ne se décela point, et il resta\nconfondu parmi le troupeau des écoliers ordinaires.',
#  "ses classes finies, balzac se donna cette seconde éducation qui est la\nvraie; il étudia, se perfectionna, suivit les cours de la sorbonne et\nfit son droit, tout en travaillant chez l'avoué et le notaire.",
#  "ce temps,\nperdu en apparence, puisque balzac ne fut ni avoué, ni notaire, ni\navocat, ni juge, lui fit connaître le personnel de la basoche et le mit\nà même d'écrire plus tard, de façon à émerveiller les hommes du métier,\nce que nous pourrions appeler le contentieux de la _comédie humaine_.",
#  'les examens passés, la grande question de la carrière à prendre se\nprésenta.',
#  "on voulait faire de balzac un notaire; mais le futur grand\nécrivain, qui, bien que personne ne crût à son génie, en avait la\nconscience, refusa le plus respectueusement du monde, quoiqu'on lui eût\nménagé une charge à des conditions très-favorables.",
#  "son père lui accorda\ndeux ans pour faire ses preuves, et comme la famille retournait en\nprovince, madame balzac installa honoré dans une mansarde, en lui\nallouant une pension suffisante à peine aux plus stricts besoins,\nespérant qu'un peu de vache enragée le rendrait plus sage.",
#  'des\nlignes partant du commencement du milieu ou de la fin des phrases, se\ndirigeaient vers les marges, à droite, à gauche, en haut, en bas,\nconduisant à des développements, à des intercalations, à des incises, à\ndes épithètes, à des adverbes.',
#  "au bout de quelques heures de travail, on\neût dit le bouquet d'un feu d'artifice dessiné par un enfant.",
#  "six, sept et parfois dix épreuves revenaient raturées, remaniées, sans\nsatisfaire le désir de perfection de l'auteur.",
#  "nous avons vu aux\njardies, sur les rayons d'une bibliothèque composée de ses oeuvres\nseules, chaque épreuve différente du même ouvrage reliée en un volume\nséparé, depuis le premier jet jusqu'au livre définitif; la comparaison\nde la pensée de balzac à ses divers états offrirait une étude bien\ncurieuse et contiendrait de profitables leçons littéraires.",
#  "balzac, comme vichnou, le dieu indien, possédait le don d'_avatar_,\nc'est-à-dire celui de s'incarner dans des corps différents et d'y vivre\nle temps qu'il voulait; seulement le nombre des _avatars_ de vichnou est\nfixé à dix, ceux de balzac ne se comptent pas, et de plus il pouvait les\nprovoquer à volonté.--quoique cela semble singulier en plein\ndix-neuvième siècle, balzac fut un _voyant_.",
#  "son mérite d'observateur,\nsa perspicacité de physiologiste, son génie d'écrivain, ne suffisent pas\npour expliquer l'infinie variété des deux ou trois mille types qui\njouent un rôle plus ou moins important dans la _comédie humaine_.",
#  "il ne\nles copiait pas, il les vivait idéalement, revêtait leurs habits,\ncontractait leurs habitudes, s'entourait de leur milieu, était eux-mêmes\ntout le temps nécessaire.",
#  "de là viennent ces personnages soutenus,\nlogiques, ne se démentant et ne s'oubliant jamais, doués d'une existence\nintime et profonde, qui, pour nous servir d'une de ses expressions, font\nconcurrence à l'état civil.",
#  "un véritable sang rouge circule dans leurs\nveines, au lieu de l'encre qu'infusent à leurs créations les auteurs\nordinaires.",
#  "cette faculté, balzac ne la possédait d'ailleurs que pour le présent.",
#  "il\npouvait transporter sa pensée dans un marquis, dans un financier, dans\nun bourgeois, dans un homme du peuple, dans une femme du monde, dans une\ncourtisane; mais les ombres du passé n'obéissaient pas à son appel: il\nne sut jamais, comme goethe, évoquer du fond de l'antiquité la belle\nhélène et lui faire habiter le manoir gothique de faust.",
#  "sauf deux ou\ntrois exceptions, toute son oeuvre est moderne; il s'était assimilé les\nvivants, il ne ressuscitait pas les morts.",
#  "l'on a fait nombre de critiques sur balzac et parlé de lui de bien des\nfaçons, mais on n'a pas insisté sur un point très-caractéristique à\nnotre avis;--ce point est la modernité absolue de son génie.",
#  "balzac ne\ndoit rien à l'antiquité;--pour lui il n'y a ni grecs ni romains, et il\nn'a pas besoin de crier qu'on l'en délivre.",
#  "balzac, comme gavarni, a vu\nses contemporains; et dans l'art, la difficulté suprême c'est de peindre\nce qu'on a devant les yeux.",
#  'cette profonde compréhension des choses modernes rendait, il faut le\ndire, balzac peu sensible à la beauté plastique.',
#  "il lisait d'un oeil\nnégligent les blanches strophes de marbre où l'art grec chanta la\nperfection de la forme humaine.",
#  "il\navait, avec un coeur très-bon et très-tendre, l'égoïsme du grand\ntravailleur.",
#  "et qui eût songé à lui en vouloir de négligences forcées et\nd'oublis apparents, lorsqu'on voyait les résultats de ses fuites ou de\nses réclusions?",
#  "quand, l'oeuvre parachevée, il reparaissait, on eût dit\nqu'il vous eût quitté la veille, et il reprenait la conversation\ninterrompue, comme si quelquefois six mois et plus ne se fussent pas\nécoulés.",
#  'il faisait des voyages en france pour étudier les localités où\nil plaçait ses _scènes de province_, et se retirait chez des amis, en\ntouraine, ou dans la charente, trouvant là un calme que ses créanciers\nne lui laissaient pas toujours à paris.',
#  "après quelque grand ouvrage, il\nse permettait parfois une excursion plus longue, en allemagne, dans la\nhaute italie ou en suisse; mais ces courses faites rapidement, avec des\npréoccupations d'échéances à payer, de traites à remplir, et un viatique\nassez borné, le fatiguaient peut-être plus qu'elles ne le reposaient.",
#  'passons maintenant à quelques détails plus intimes.',
#  'le grand goethe\navait trois choses en horreur: une de ces choses était la fumée de\ntabac; on nous dispensera de dire les deux autres.',
#  "balzac, comme le\njupiter de l'olympe poétique allemand, ne pouvait souffrir le tabac sous\nquelque forme que ce fût; il ne fuma jamais.",
#  "toutes les fois que balzac\nest obligé, pour la vraisemblance du récit, de laisser un de ses\npersonnages s'adonner à cette habitude horrible du tabac, sa phrase\nbrève et dédaigneuse trahit un secret blâme: «quant à de marsay, dit-il,\nil était occupé à fumer ses cigares.» et il faut qu'il aime bien ce\ncondottiere du dandysme pour lui permettre de fumer dans son oeuvre.",
#  'une femme délicate et petite-maîtresse avait sans doute imposé cette\naversion à balzac.',
#  "c'est un point que nous ne saurions résoudre.",
#  "toujours est-il qu'il ne fit pas gagner un sou à la régie.",
#  "a propos de\nfemmes, balzac, qui les a si bien peintes, devait les connaître, et l'on\nsait le sens que la bible attache à ce mot.",
#  "dans une des lettres qu'il\nécrit à madame de surville, sa soeur, balzac, tout jeune et complétement\nignoré, pose l'idéal de sa vie en deux mots: «être célèbre et être\naimé.» la première partie de ce programme, que se tracent du reste tous\nles artistes, a été réalisée de point en point.",
#  'la seconde a-t-elle reçu\nson accomplissement?',
#  "l'opinion des plus intimes amis de balzac est qu'il\npratiqua la chasteté qu'il recommandait aux autres, et n'eut que des\namours platoniques; mais madame de surville sourit à cette idée, avec un\nsourire d'une finesse féminine et tout plein de pudiques réticences.",
#  "elle prétend que son frère était d'une discrétion à toute épreuve, et\nque s'il eût voulu parler, il eût eu beaucoup de choses à dire.",
#  "cela\ndoit être, et sans doute la cassette de balzac contenait plus de petites\nlettres à l'écriture fine et penchée que la boîte en laque de canalis.",
#  'il y a dans son oeuvre comme une odeur de femme: _odor di femina_.',
#  "quand\non y entre, on entend, derrière les portes qui se referment, sur les\nmarches de l'escalier dérobé, des frou-frou de soie et des craquements\nde bottines.",
#  "le salon semi-circulaire et matelassé de la rue des\nbatailles, dont la description est placée par l'auteur dans _la fille\naux yeux d'or_, ne resta donc pas complétement virginal, comme plusieurs\nde nous le supposèrent.",
#  'dîmes-nous en riant à\nbalzac en face de ces splendeurs; vous voyez bien que nous avions raison\nen vous prétendant millionnaire.',
#  "--je suis plus pauvre que jamais, répondait-il en prenant un air humble\net papelard; rien de tout cela n'est à moi.",
#  "j'ai meublé la maison pour\nun ami qu'on attend.--je ne suis que le gardien et le portier de\nl'hôtel!»\n\nnous citons là ses paroles textuelles.",
#  "cette réponse, il la fit\nd'ailleurs à plusieurs personnes étonnées comme nous.",
#  "le mystère\ns'expliqua bientôt par le mariage de balzac avec la femme qu'il aimait\ndepuis longtemps.",
#  'il y a un proverbe turc qui dit.',
#  "«quand la maison est finie, la mort\nentre.» c'est pour cela que les sultans ont toujours un palais en\nconstruction qu'ils se gardent bien d'achever.",
#  'la vie semble ne vouloir\nrien de complet--que le malheur.',
#  "rien n'est redoutable comme un souhait\nréalisé.",
#  "les fameuses dettes étaient enfin payées, l'union rêvée accomplie, le\nnid pour le bonheur ouaté et garni de duvet; comme s'ils eussent\npressenti sa fin prochaine, les envieux de balzac commençaient à le\nlouer: les _parents pauvres_, le _cousin pons_, où le génie de l'auteur\nbrille de tout son éclat, ralliaient tous les suffrages.--c'était trop\nbeau; il ne lui restait plus qu'à mourir.",
#  "sa maladie fit de rapides progrès, mais personne ne croyait à un\ndénoûment fatal, tant on avait confiance dans l'athlétique organisation\nde balzac.",
#  "nous pensions fermement qu'il nous enterrerait tous.",
#  'huit ans déjà se sont écoulés depuis la mort de balzac[1].',
#  'la postérité\na commencé pour lui; chaque jour il semble plus grand.',
#  "lorsqu'il était\nmêlé à ses contemporains, on l'appréciait mal, on ne le voyait que par\nfragments, sous des aspects parfois défavorables: maintenant l'édifice\nqu'il a bâti s'élève à mesure qu'on s'en éloigne, comme la cathédrale\nd'une ville que masquaient les maisons voisines, et qui à l'horizon se\ndessine immense au-dessus des toits aplatis.",
#  "le monument n'est pas\nachevé; mais tel qu'il est, il effraye par son énormité, et les\ngénérations surprises se demanderont quel est le géant qui a soulevé\nseul ces blocs formidables et monté si haut cette babel où bourdonne\ntoute une société.",
#  "[1] 18 août 1850.\n\nquoique mort, balzac a pourtant encore des détracteurs; on jette à sa\nmémoire ce reproche banal d'immoralité, dernière injure de la médiocrité\nimpuissante et jalouse, ou même de la pure bêtise.",
#  "l'auteur de la\n_comédie humaine_, non-seulement n'est pas immoral, mais c'est même un\nmoraliste austère.",
#  "monarchique et catholique, il défend l'autorité,\nexalte la religion, prêche le devoir, morigène la passion, et n'admet le\nbonheur que dans le mariage et la famille.",
#  'théophile gautier.',
#  "avant-propos\n\n\nen donnant à une oeuvre entreprise depuis bientôt treize ans, le titre\nde _la comédie humaine_, il est nécessaire d'en dire la pensée, d'en\nraconter l'origine, d'en expliquer brièvement le plan, en essayant de\nparler de ces choses comme si je n'y étais pas intéressé.",
#  "ceci n'est pas\naussi difficile que le public pourrait le penser.",
#  "peu d'oeuvres donne\nbeaucoup d'amour-propre, beaucoup de travail donne infiniment de\nmodestie.",
#  "cette observation rend compte des examens que corneille,\nmolière et autres grands auteurs faisaient de leurs ouvrages: s'il est\nimpossible de les égaler dans leurs belles conceptions, on peut vouloir\nleur ressembler en ce sentiment.",
#  "l'idée première de _la comédie humaine_ fut d'abord chez moi comme un\nrêve, comme un de ces projets impossibles que l'on caresse et qu'on\nlaisse s'envoler; une chimère qui sourit, qui montre son visage de femme\net qui déploie aussitôt ses ailes en remontant dans un ciel fantastique.",
#  'mais la chimère, comme beaucoup de chimères, se change en réalité, elle\na ses commandements et sa tyrannie auxquels il faut céder.',
#  "cette idée vint d'une comparaison entre l'humanité et l'animalité.",
#  "ce serait une erreur de croire que la grande querelle qui, dans ces\nderniers temps, s'est émue entre cuvier et geoffroi saint-hilaire,\nreposait sur une innovation scientifique.",
#  "l'_unité de composition_\noccupait déjà sous d'autres termes les plus grands esprits des deux\nsiècles précédents.",
#  "en relisant les oeuvres si extraordinaires des\nécrivains mystiques qui se sont occupés des sciences dans leurs\nrelations avec l'infini, tels que swedenborg, saint-martin, etc., et les\nécrits des plus beaux génies en histoire naturelle, tels que leibnitz,\nbuffon, charles bonnet, etc., on trouve dans les monades de leibnitz,\ndans les molécules organiques de buffon, dans la force végétatrice de\nneedham, dans l'_emboîtement_ des parties similaires de charles bonnet,\nassez hardi pour écrire en 1760: _l'animal végète comme la plante_; on\ntrouve, dis-je, les rudiments de la belle loi du _soi pour soi_ sur\nlaquelle repose l'_unité de composition_.",
#  "il n'y a qu'un animal.",
#  "le\ncréateur ne s'est servi que d'un seul et même patron pour tous les êtres\norganisés.",
#  "l'animal est un principe qui prend sa forme extérieure, ou,\npour parler plus exactement, les différences de sa forme, dans les\nmilieux où il est appelé à se développer.",
#  'les espèces zoologiques\nrésultent de ces différences.',
#  "la proclamation et le soutien de ce\nsystème, en harmonie d'ailleurs avec les idées que nous nous faisons de\nla puissance divine, sera l'éternel honneur de geoffroi saint-hilaire,\nle vainqueur de cuvier sur ce point de la haute science, et dont le\ntriomphe a été salué par le dernier article qu'écrivit le grand goethe.",
#  'pénétré de ce système bien avant les débats auxquels il a donné lieu, je\nvis que, sous ce rapport, la société ressemblait à la nature.',
#  "la société\nne fait-elle pas de l'homme, suivant les milieux où son action se\ndéploie, autant d'hommes différents qu'il y a de variétés en zoologie?",
#  "les différences entre un soldat, un ouvrier, un administrateur, un\navocat, un oisif, un savant, un homme d'état, un commerçant, un marin,\nun poëte, un pauvre, un prêtre, sont, quoique plus difficiles à saisir,\naussi considérables que celles qui distinguent le loup, le lion, l'âne,\nle corbeau, le requin, le veau marin, la brebis, etc. il a donc existé,\nil existera donc de tout temps des espèces sociales comme il y a des\nespèces zoologiques.",
#  "si buffon a fait un magnifique ouvrage en essayant\nde représenter dans un livre l'ensemble de la zoologie, n'y avait-il pas\nune oeuvre de ce genre à faire pour la société?",
#  'mais la nature a posé,\npour les variétés animales, des bornes entre lesquelles la société ne\ndevait pas se tenir.',
#  'quand buffon peignait le lion, il achevait la\nlionne en quelques phrases; tandis que dans la société la femme ne se\ntrouve pas toujours être la femelle du mâle.',
#  'il peut y avoir deux êtres\nparfaitement dissemblables dans un ménage.',
#  "d'abord,\npresque toujours ces personnages, dont l'existence devient plus longue,\nplus authentique que celle des générations au milieu desquelles on les\nfait naître, ne vivent qu'à la condition d'être une grande image du\nprésent.",
#  "conçus dans les entrailles de leur siècle, tout le coeur humain\nse remue sous leur enveloppe, il s'y cache souvent toute une\nphilosophie.",
#  "walter scott élevait donc à la valeur philosophique de\nl'histoire le roman, cette littérature qui, de siècle en siècle,\nincruste d'immortels diamants la couronne poétique des pays où se\ncultivent les lettres.",
#  "il y mettait l'esprit des anciens temps, il y\nréunissait à la fois le drame, le dialogue, le portrait, le paysage, la\ndescription; il y faisait entrer le merveilleux et le vrai, ces éléments\nde l'épopée, il y faisait coudoyer la poésie par la familiarité des plus\nhumbles langages.",
#  "mais, ayant moins imaginé un système que trouvé sa\nmanière dans le feu du travail ou par la logique de ce travail, il\nn'avait pas songé à relier ses compositions l'une à l'autre de manière à\ncoordonner une histoire complète, dont chaque chapitre eût été un roman,\net chaque roman une époque.",
#  "en apercevant ce défaut de liaison, qui\nd'ailleurs ne rend pas l'écossais moins grand, je vis à la fois le\nsystème favorable à l'exécution de mon ouvrage et la possibilité de\nl'exécuter.",
#  "quoique, pour ainsi dire, ébloui par la fécondité\nsurprenante de walter scott, toujours semblable à lui-même et toujours\noriginal, je ne fus pas désespéré, car je trouvai la raison de ce talent\ndans l'infinie variété de la nature humaine.",
#  "le hasard est le plus grand\nromancier du monde: pour être fécond, il n'y a qu'à l'étudier.",
#  "la\nsociété française allait être l'historien, je ne devais être que le\nsecrétaire.",
#  "en dressant l'inventaire des vices et des vertus, en\nrassemblant les principaux faits des passions, en peignant les\ncaractères, en choisissant les événements principaux de la société, en\ncomposant des types par la réunion des traits de plusieurs caractères\nhomogènes, peut-être pouvais-je arriver à écrire l'histoire oubliée par\ntant d'historiens, celle des moeurs.",
#  "avec beaucoup de patience et de\ncourage, je réaliserais, sur la france au dix-neuvième siècle, ce livre\nque nous regrettons tous, que rome, athènes, tyr, memphis, la perse,\nl'inde ne nous ont malheureusement pas laissé sur leurs civilisations,\net qu'à l'instar de l'abbé barthélemy, le courageux et patient monteil\navait essayé pour le moyen-age, mais sous une forme peu attrayante.",
#  "ce travail n'était rien encore.",
#  "s'en tenant à cette reproduction\nrigoureuse, un écrivain pouvait devenir un peintre plus ou moins fidèle,\nplus ou moins heureux, patient ou courageux des types humains, le\nconteur des drames de la vie intime, l'archéologue du mobilier social,\nle nomenclateur des professions, l'enregistreur du bien et du mal; mais,\npour mériter les éloges que doit ambitionner tout artiste, ne devais-je\npas étudier les raisons ou la raison de ces effets sociaux, surprendre\nle sens caché dans cet immense assemblage de figures, de passions et\nd'événements.",
#  "enfin, après avoir cherché, je ne dis pas trouvé, cette\nraison, ce moteur social, ne fallait-il pas méditer sur les principes\nnaturels et voir en quoi les sociétés s'écartent ou se rapprochent de la\nrègle éternelle, du vrai, du beau?",
# ...
#  'a six heures et demie, la salle à manger, illustrée par le\npeintre, réunit sous son toit de verre madame et monsieur roguin, le\njeune peintre et sa charmante augustine, joseph lebas qui prenait son\nbonheur en patience, et mademoiselle virginie dont la migraine avait\ncessé.',
#  'monsieur et madame guillaume virent en perspective leurs enfants\nétablis et les destinées du chat-qui-pelote remises en des mains\nhabiles.',
#  "leur contentement fut au comble, quand, au dessert, théodore\nleur fit présent de l'étonnant tableau qu'ils n'avaient pu voir, et qui\nreprésentait l'intérieur de cette vieille boutique, à laquelle était dû\ntant de bonheur.",
#  "--c'est-y gentil!",
#  "s'écria guillaume.",
#  "dire qu'on voulait donner trente\nmille francs de cela.",
#  "--mais c'est qu'on y trouve mes barbes, reprit madame guillaume.",
#  '--et ces étoffes dépliées, ajouta lebas, on les prendrait avec la main.',
#  '--les draperies font toujours très-bien, répondit le peintre.',
#  "nous\nserions trop heureux, nous autres artistes modernes, d'atteindre à la\nperfection de la draperie antique.",
#  "--vous aimez donc la draperie, s'écria le père guillaume.",
#  'eh bien,\nsarpejeu!',
#  'touchez là, mon jeune ami.',
#  'puisque vous estimez le commerce,\nnous nous entendrons.',
#  'eh!',
#  'pourquoi le mépriserait-on?',
#  'le monde a\ncommencé par là, puisque adam a vendu le paradis pour une pomme.',
#  "ça n'a\npas été une fameuse spéculation, par exemple!",
#  "et le vieux négociant se mit à éclater d'un gros rire franc excité par\nle vin de champagne qu'il faisait circuler généreusement.",
#  "le bandeau qui\ncouvrait les yeux du jeune artiste fut si épais qu'il trouva ses futurs\nparents aimables.",
#  'il ne dédaigna pas de les égayer par quelques charges\nde bon goût.',
#  'aussi plut-il généralement.',
#  "le soir, quand le salon meublé\nde choses très-cossues, pour se servir de l'expression de guillaume, fut\ndésert; pendant que madame guillaume s'en allait de table en cheminée,\nde candélabre en flambeau, soufflant avec précipitation les bougies, le\nbrave négociant, qui savait toujours voir clair aussitôt qu'il\ns'agissait d'affaires ou d'argent, attira sa fille augustine auprès de\nlui; puis, après l'avoir prise sur ses genoux, il lui tint ce discours:\n\n--ma chère enfant, tu épouseras ton sommervieux, puisque tu le veux;\npermis à toi de risquer ton capital de bonheur.",
#  "mais je ne me laisse pas\nprendre à ces trente mille francs que l'on gagne à gâter de bonnes\ntoiles.",
#  "l'argent qui vient si vite s'en va de même.",
#  "n'ai-je pas entendu\ndire ce soir à ce jeune écervelé que si l'argent était rond, c'était\npour rouler!",
#  "s'il est rond pour les gens prodigues, il est plat pour les\ngens économes qui l'empilent et l'amassent.",
#  'or, mon enfant, ce beau\ngarçon-là parle de te donner des voitures, des diamants?',
#  "il a de\nl'argent, qu'il le dépense pour toi!",
#  "_bene sit!_ je n'ai rien à y voir.",
#  "mais quant à ce que je te donne, je ne veux pas que des écus si\npéniblement ensachés s'en aillent en carrosses ou en colifichets.",
#  "qui\ndépense trop n'est jamais riche.",
#  "avec les cent mille écus de sa dot on\nn'achète pas encore tout paris.",
#  'tu as beau avoir à recueillir un jour\nquelques centaines de mille francs, je te les ferai attendre, sarpejeu!',
#  'le plus longtemps possible.',
#  "j'ai donc attiré ton prétendu dans un coin,\net un homme qui a mené la faillite lecoq n'a pas eu grande peine à faire\nconsentir un artiste à se marier séparé de biens avec sa femme.",
#  "j'aurai\nl'oeil au contrat pour bien faire stipuler les donations qu'il se\npropose de te constituer.",
#  "allons, mon enfant, j'espère être grand-père,\nsarpejeu!",
#  "je veux m'occuper déjà de mes petits-enfants: jure-moi donc\nici de ne jamais rien signer en fait d'argent que par mon conseil; et si\nj'allais trouver trop tôt le père chevrel, jure-moi de consulter le\njeune lebas, ton beau-frère.",
#  'promets-le-moi.',
#  '--oui, mon père, je vous le jure.',
#  "a ces mots prononcés d'une voix douce, le vieillard baisa sa fille sur\nles deux joues.",
#  'ce soir-là, tous les amants dormirent presque aussi\npaisiblement que monsieur et madame guillaume.',
#  'quelques mois après ce mémorable dimanche, le maître-autel de saint-leu\nfut témoin de deux mariages bien différents.',
#  "augustine et théodore s'y\nprésentèrent dans tout l'éclat du bonheur, les yeux pleins d'amour,\nparés de toilettes élégantes, attendus par un brillant équipage.",
#  'venue\ndans un bon remise avec sa famille, virginie, donnant le bras à son\npère, suivait sa jeune soeur humblement et dans de plus simples atours,\ncomme une ombre nécessaire aux harmonies de ce tableau.',
#  "monsieur\nguillaume s'était donné toutes les peines imaginables pour obtenir à\nl'église que virginie fût mariée avant augustine; mais il eut la douleur\nde voir le haut et le bas clergé s'adresser en toute circonstance à la\nplus élégante des mariées.",
#  "il entendit quelques-uns de ses voisins\napprouver singulièrement le bon sens de mademoiselle virginie, qui\nfaisait, disaient-ils, le mariage le plus solide, et restait fidèle au\nquartier; tandis qu'ils lancèrent quelques brocards suggérés par l'envie\nsur augustine qui épousait un artiste, un noble; ils ajoutèrent avec une\nsorte d'effroi que, si les guillaume avaient de l'ambition, la draperie\nétait perdue.",
#  "un vieux marchand d'éventails ayant dit que ce\nmange-tout-là l'aurait bientôt mise sur la paille, le père guillaume\ns'applaudit _in petto_ de la prudence qu'il avait mise dans la rédaction\ndes conventions matrimoniales.",
#  "le soir, la famille se sépara après un\nbal somptueux, suivi d'un de ces soupers plantureux dont le souvenir\ncommence à se perdre dans la génération présente.",
#  'monsieur et madame\nguillaume restèrent dans leur hôtel de la rue du colombier où la noce\navait eu lieu.',
#  'monsieur et madame lebas retournèrent dans leur remise à\nla vieille maison de la rue saint-denis, pour y diriger la nauf du\nchat-qui-pelote.',
#  "l'artiste, ivre de bonheur, prit entre ses bras sa\nchère augustine, l'enleva vivement quand leur coupé arriva rue des\ntrois-frères, et la porta dans son élégant appartement.",
#  "la fougue de passion qui possédait théodore fit dévorer au jeune ménage\nprès d'une année entière sans que le moindre nuage vînt altérer l'azur\ndu ciel sous lequel ils vivaient.",
#  "pour eux, l'existence n'eut rien de\npesant.",
#  "théodore répandait sur chaque journée d'incroyables _fioriture_\nde plaisirs.",
#  "il se plaisait à varier les emportements de la passion, par\nla molle langueur de ces repos où les âmes sont lancées si haut dans\nl'extase qu'elles semblent y oublier l'union corporelle.",
#  "quand les champs de\nl'amour furent parcourus, quand l'artiste eut, comme les enfants,\ncueilli des roses et des bluets avec une telle avidité qu'il ne\ns'apercevait pas que ses mains ne pouvaient plus les tenir, la scène\nchangea.",
#  "si le peintre montrait à sa femme les croquis de ses plus\nbelles compositions, il l'entendait s'écrier comme eût fait le père\nguillaume:--c'est bien joli!",
#  "son admiration sans chaleur ne provenait\npas d'un sentiment consciencieux, mais de la croyance sur parole de\nl'amour.",
#  'augustine préférait un regard au plus beau tableau.',
#  "le seul\nsublime qu'elle connût était celui du coeur.",
#  "enfin, théodore ne put se\nrefuser à l'évidence d'une vérité cruelle: sa femme n'était pas sensible\nà la poésie, elle n'habitait pas sa sphère, elle ne le suivait pas dans\ntous ses caprices, dans ses improvisations, dans ses joies, dans ses\ndouleurs; elle marchait terre à terre dans le monde réel, tandis qu'il\navait la tête dans les cieux.",
#  "les esprits ordinaires ne peuvent pas\napprécier les souffrances renaissantes de l'être qui, uni à un autre par\nle plus intime de tous les sentiments, est obligé de refouler sans cesse\nles plus chères expansions de sa pensée, et de faire rentrer dans le\nnéant les images qu'une puissance magique le force à créer.",
#  "pour lui, ce\nsupplice est d'autant plus cruel, que le sentiment qu'il porte à son\ncompagnon ordonne, par sa première loi, de ne jamais rien se dérober\nl'un à l'autre, et de confondre les effusions de la pensée aussi bien\nque les épanchements de l'âme.",
#  'on ne trompe pas impunément les volontés\nde la nature: elle est inexorable comme la nécessité, qui, certes, est\nune sorte de nature sociale.',
#  "sommervieux se réfugia dans le calme et le\nsilence de son atelier, en espérant que l'habitude de vivre avec des\nartistes pourrait former sa femme, et développerait en elle les germes\nde haute intelligence engourdis que quelques esprits supérieurs croient\npréexistants chez tous les êtres; mais augustine était trop sincèrement\nreligieuse pour ne pas être effrayée du ton des artistes.",
#  "au premier\ndîner que donna théodore, elle entendit un jeune peintre disant avec\ncette enfantine légèreté qu'elle ne sut pas reconnaître et qui absout\nune plaisanterie de toute irréligion:--mais, madame, votre paradis n'est\npas plus beau que la transfiguration de raphaël?",
#  'eh!',
#  'bien, je me suis\nlassé de la regarder.',
#  "augustine apporta donc dans cette société\nspirituelle un esprit de défiance qui n'échappait à personne.",
#  'elle gêna.',
#  'les artistes gênés sont impitoyables: ils fuient ou se moquent.',
#  "madame\nguillaume avait, entre autres ridicules, celui d'outrer la dignité qui\nlui semblait l'apanage d'une femme mariée; et quoiqu'elle s'en fût\nsouvent moqué, augustine ne sut pas se défendre d'une légère imitation\nde la pruderie maternelle.",
#  "cette exagération de pudeur, que n'évitent\npas toujours les femmes vertueuses, suggéra quelques épigrammes à coups\nde crayon dont l'innocent badinage était de trop bon goût pour que\nsommervieux pût s'en fâcher.",
#  "ces plaisanteries eussent été même plus\ncruelles, elles n'étaient après tout que des représailles exercées sur\nlui par ses amis.",
#  'mais rien ne pouvait être léger pour une âme qui\nrecevait aussi facilement que celle de théodore des impressions\nétrangères.',
#  "aussi éprouva-t-il insensiblement une froideur qui ne\npouvait aller qu'en croissant.",
#  "pour arriver au bonheur conjugal, il faut\ngravir une montagne dont l'étroit plateau est bien près d'un revers\naussi rapide que glissant, et l'amour du peintre le descendait.",
#  "il jugea\nsa femme incapable d'apprécier les considérations morales qui\njustifiaient, à ses propres yeux, la singularité de ses manières envers\nelle, et se crut fort innocent en lui cachant des pensées qu'il ne\ncomprenait pas et des écarts peu justiciables au tribunal d'une\nconscience bourgeoise.",
#  'augustine se renferma dans une douleur morne et\nsilencieuse.',
#  "ces sentiments secrets mirent entre les deux époux un voile\nqui devait s'épaissir de jour en jour.",
#  "sans que son mari manquât\nd'égards envers elle, augustine ne pouvait s'empêcher de trembler en le\nvoyant réserver pour le monde les trésors d'esprit et de grâce qu'il\nvenait jadis mettre à ses pieds.",
#  "bientôt, elle interpréta fatalement les\ndiscours spirituels qui se tiennent dans le monde sur l'inconstance des\nhommes.",
#  'elle ne se plaignit pas, mais son attitude équivalait à des\nreproches.',
#  "trois ans après son mariage, cette femme jeune et jolie qui\npassait si brillante dans son brillant équipage, qui vivait dans une\nsphère de gloire et de richesse enviée de tant de gens insouciants et\nincapables d'apprécier justement les situations de la vie, fut en proie\nà de violents chagrins.",
#  'ses couleurs pâlirent.',
#  "elle réfléchit, elle\ncompara; puis, le malheur lui déroula les premiers textes de\nl'expérience.",
#  "elle résolut de rester courageusement dans le cercle de\nses devoirs, en espérant que cette conduite généreuse lui ferait\nrecouvrer tôt ou tard l'amour de son mari; mais il n'en fut pas ainsi.",
#  "quand sommervieux, fatigué de travail, sortait de son atelier, augustine\nne cachait pas si promptement son ouvrage, que le peintre ne pût\napercevoir sa femme raccommodant avec toute la minutie d'une bonne\nménagère le linge de la maison et le sien.",
#  "elle fournissait, avec\ngénérosité, sans murmure, l'argent nécessaire aux prodigalités de son\nmari; mais, dans le désir de conserver la fortune de son cher théodore,\nelle se montrait économe soit pour elle, soit dans certains détails de\nl'administration domestique.",
#  ...]

# %%
nbToken = sum([len(x) for x in wordSents])
nbToken
# Out:
# 2335258

# %% [markdown]
# Extraire un fragment (environ 2000 mots) qui servira de donnée de test (pas le bon format, utiliser C.H. 10).

# %%
import random
nbWordsTaken = 0
randomizedSet = wordSents
random.shuffle(randomizedSet)
trainSet = []
testSet = []

for sent in randomizedSet:
    nbWordsTaken += len(sent)
    if(nbWordsTaken < 2000):
        testSet.append(sent)
    else:
        index = randomizedSet.index(sent)
        break
trainSet = randomizedSet[index:]

print("Taille train set: " + str(len(trainSet)) + "\nTaille test set: " + str(len(testSet)))
# Out:
# Taille train set: 101143
# Taille test set: 95

# %%
print("Nombre de mots dans le set de test: " + str(sum([len(x) for x in testSet])))
# Out:
# Nombre de mots dans le set de test: 1993

# %% [markdown]
# Sauvegarder aussi chaque liste dans un fichier pickle.

# %%
import pickle 
file_pickle1 = open('tarinSet.obj', 'wb')
file_pickle2 = open('testSet.obj', 'wb')
pickle.dump(trainSet, file_pickle1)
pickle.dump(testSet, file_pickle2)

# %% [markdown]
# ## Entraîner un premier modèle de langage de NLTK

# %% [markdown]
# En utilisant les instructions disponibles pour le module NLTK LM, entraîner un modèle de langage sur les données d'entraînement. Attention, le package lm n'est disponible qu'à partir de NLTK version 3.4.

# %%
from nltk.lm import MLE
from nltk.lm import Vocabulary

# %% [markdown]
# Commencer avec un modèle MLE à l'ordre 2, comme montré dans le tutoriel.

# %%
# paddedLine found at https://stackoverflow.com/questions/54959340/nltk-language-modeling-confusion
from nltk.lm.preprocessing import pad_both_ends, padded_everygram_pipeline
train, vocab = padded_everygram_pipeline(2, trainSet)

# %%
lm = MLE(2)
lm.fit(train, vocab)
lm.generate(3)
# Out:
# [',', 'des', 'vertus']

# %% [markdown]
# Puis, par exemple, aller jusqu'à l'ordre 3 ou 4, avec l'algorithme de Laplace (ou de Kneser-Ney).

# %%
train, vocab = padded_everygram_pipeline(4, trainSet)
lm = MLE(4)
lm.fit(train, vocab)

# %% [markdown]
# Calculer la perplexité du modèle sur l’ensemble de test.

# %%
lm.perplexity(testSet)
# Out:
# inf

# %% [markdown]
# Notre résultat est infini car certains mots du test set ne font pas partie du vocabulaire défini.

# %% [markdown]
# Générer quelques phrases dans le style de Balzac selon les explications de NLTK.

# %%
lm.generate(text_seed=['Je', 'ne','suis', 'pas'], num_words=2)
# Out:
# ['assez', 'forte']

# %%
lm.generate(text_seed=['Quand', 'il'], num_words=8)
# Out:
# ['descendit', 'en', 'emportant', 'cette', 'pièce', 'de', 'conviction', ',']

# %%
print(lm.generate(text_seed=['Quand', 'il'], num_words=8))
# Out:
# ["s'aperçut", "qu'il", 'avait', 'plu', 'à', 'tout', 'le', 'monde']

# %%
lm.generate(text_seed=['Rien', 'ne', 'pourra', 'jamais'], num_words=3)
# Out:
# ['greffer', 'un', 'livre']

# %%
lm.generate(text_seed=['J\'aime' 'bien'], num_words=2)
# Out:
# ['la', 'grâce']

# %%
print("Ma sœur n'est qu'une " + str(lm.generate(text_seed=['Ma', 'sœur', 'n\'est', 'qu\'une'], num_words=1)))
# Out:
# Ma sœur n'est qu'une scélérate

# %%
print("Yohann Meyer est très, très " + str(lm.generate(text_seed=['Yohann', 'Meyer', 'est', 'très', ',', 'très'], num_words=1)))
# Out:
# Yohann Meyer est très, très usé

# %% [markdown]
# ## Entraîner un second modèle de langage de NLTK

# %% [markdown]
# En utilisant par exemple le modèle de Laplace.

# %%
from nltk.lm import Laplace
lm2 = Laplace(4)

# %% [markdown]
# Le tester aussi sur le corpus de test et comparer les scores.

# %%
lm2.fit(train, vocab)

# %%
lm2.unmasked_score
# Out:
# <bound method Lidstone.unmasked_score of <nltk.lm.models.Laplace object at 0x7fc276763240>>

# %% [markdown]
# ## Cloze test

# %% [markdown]
# Supprimer un mot sur 7 dans le corpus de test.

# %% [markdown]
# En utilisant la méthode lm.generate avec du contexte, demander au modèle de langage de prédire ces mots (en utilisant donc 2-4 mots précédents). Quelle est la performance du système ? Comparer les modèles générés en (2) et en (3).

# %% [markdown]
# Générez un texte avec les mots en question (1 mot sur 7) remplacés par des blancs, et passez-le à un autre binôme : quelle est leur performance pour deviner les mots ?

# %% [markdown]
# Merci d’envoyer votre notebook Jupyter par email au professeur avant le vendredi 14 juin à 23h59.
